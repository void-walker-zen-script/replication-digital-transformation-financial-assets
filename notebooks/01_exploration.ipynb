# %% [markdown]
# # Exploratory analysis
#
# This notebook is intentionally empty of company data and empirical results. Use it only after obtaining lawful local data access. Do not commit executed cells containing company-level observations.

# %%
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent
DATA_DIR = PROJECT_ROOT / "data"
PROJECT_ROOT

# %% [markdown]
# Suggested checks after real data are prepared locally:
#
# 1. Confirm `firm_id-year` uniqueness.
# 2. Inspect missing values and variable units.
# 3. Compare financial-asset component sums with the total.
# 4. Review keyword counts for a small, manually checked report sample.
# 5. Remove cell outputs before committing the notebook.
